# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# __Q1. Load the dataset and display first 5 rows?__

# %%
df = pd.read_csv('Esha Zia - content_based_recommendation_dataset.csv')

# %%
df
# Out:
#       Number of clicks on similar products  \
# 0                                       12
# 1                                        8
# 2                                       25
# 3                                        6
# 4                                       18
# ...                                    ...
# 1469                                     5
# 1470                                    37
# 1471                                    22
# 1472                                    40
# 1473                                    12
#
#       Number of similar products purchased so far  \
# 0                                               4
# 1                                               2
# 2                                              10
# 3                                               1
# 4                                               5
# ...                                           ...
# 1469                                            1
# ...

# %%
df.head(5)
# Out:
#    Number of clicks on similar products  \
# 0                                    12
# 1                                     8
# 2                                    25
# 3                                     6
# 4                                    18
#
#    Number of similar products purchased so far  \
# 0                                            4
# 1                                            2
# 2                                           10
# 3                                            1
# 4                                            5
#
#    Average rating given to similar products  Gender  \
# 0                                       4.2    male
# 1                                       3.8  female
# 2                                       4.5  female
# 3                                       2.1  female
# 4                                       4.7    male
#
#    Median purchasing price (in rupees)  Rating of the product  \
# ...

# %% [markdown]
# __Q2. Display dataset shape and column names?__

# %%
df.shape
# Out:
# (1474, 13)

# %%
df.columns
# Out:
# Index(['Number of clicks on similar products',
#        'Number of similar products purchased so far',
#        'Average rating given to similar products', 'Gender',
#        'Median purchasing price (in rupees)', 'Rating of the product',
#        'Brand of the product', 'Customer review sentiment score (overall)',
#        'Price of the product', 'Holiday', 'Season', 'Geographical locations',
#        'Probability for the product to be recommended to the person'],
#       dtype='str')

# %% [markdown]
# __Q3. Check data types of all columns?__

# %%
df.dtypes
# Out:
# Number of clicks on similar products                             int64
# Number of similar products purchased so far                      int64
# Average rating given to similar products                       float64
# Gender                                                             str
# Median purchasing price (in rupees)                              int64
# Rating of the product                                          float64
# Brand of the product                                               str
# Customer review sentiment score (overall)                      float64
# Price of the product                                             int64
# Holiday                                                            str
# Season                                                             str
# Geographical locations                                             str
# Probability for the product to be recommended to the person    float64
# dtype: object

# %% [markdown]
# __Q4. Identify missing values in each column?__

# %%
df.isnull().sum()
# Out:
# Number of clicks on similar products                           0
# Number of similar products purchased so far                    0
# Average rating given to similar products                       0
# Gender                                                         0
# Median purchasing price (in rupees)                            0
# Rating of the product                                          0
# Brand of the product                                           0
# Customer review sentiment score (overall)                      0
# Price of the product                                           0
# Holiday                                                        0
# Season                                                         0
# Geographical locations                                         0
# Probability for the product to be recommended to the person    0
# dtype: int64

# %% [markdown]
# __Q5. Handle missing values?__

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
#There are no any missing values in a dataset

# %% [markdown]
# __Q6. Check and remove duplicate rows?__

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1469    False
# 1470    False
# 1471    False
# 1472    False
# 1473    False
# Length: 1474, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 456

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# __Q7. Generate summary statistics?__

# %%
df.describe()
# Out:
#        Number of clicks on similar products  \
# count                           1474.000000
# mean                              20.846676
# std                               11.315669
# min                                0.000000
# 25%                               11.000000
# 50%                               19.000000
# 75%                               28.750000
# max                               55.000000
#
#        Number of similar products purchased so far  \
# count                                  1474.000000
# mean                                      9.225237
# std                                       5.356612
# min                                       0.000000
# 25%                                       5.000000
# 50%                                       9.000000
# 75%                                      13.000000
# max                                      24.000000
#
#        Average rating given to similar products  \
# ...

# %% [markdown]
# __Q8. Calculate the average of 'Price of the product'?__

# %%
df['Price of the product'].mean()
# Out:
# 1142.910447761194

# %% [markdown]
# __Q9. Find max and min of 'Median purchasing price (in rupees)'?__

# %%
df['Median purchasing price (in rupees)'].max()
# Out:
# 19000

# %%
df['Median purchasing price (in rupees)'].min()
# Out:
# 100

# %% [markdown]
# __Q10. Value counts of 'Brand of the product'?_

# %%
df['Brand of the product'].value_counts()
# Out:
# Brand of the product
# Wildcraft                          161
# Manyavar Mohey                     111
# Pepe Jeans London                   85
# Lakme Ayurveda                      79
# Johnson & Johnson                   76
# Pepperfry                           75
# Flying Machine                      70
# Patanjali Ayurved (Health Care)     68
# Lee                                 65
# Wakefit                             59
# Sugar Cosmetics                     42
# Head Hunters                        41
# Fastrack                            41
# Urban Ladder                        38
# Khadi Essentials                    34
# Forest Essentials                   33
# Kama Ayurveda                       32
# Himalaya Liv.52                     29
# Max                                 29
# PUMA                                25
# The Moms Co.                        23
# Dettol                              21
# SleepyCat                           20
# ...

# %% [markdown]
# __Q11. Sort data by 'Price of the product'?__

# %%
df = df.sort_values(by = 'Price of the product')

# %%
df
# Out:
#       Number of clicks on similar products  \
# 752                                     40
# 764                                     39
# 788                                     34
# 1282                                    10
# 1303                                     7
# ...                                    ...
# 863                                     35
# 1444                                    14
# 20                                      28
# 855                                     50
# 958                                     35
#
#       Number of similar products purchased so far  \
# 752                                            16
# 764                                            15
# 788                                            13
# 1282                                            0
# 1303                                            1
# ...                                           ...
# 863                                            14
# ...

# %% [markdown]
# __Q12. Filter data where rating > 4?__

# %%
df[df['Rating of the product']>4]
# Out:
#       Number of clicks on similar products  \
# 0                                       12
# 2                                       25
# 4                                       18
# 6                                       38
# 9                                       10
# ...                                    ...
# 1467                                    43
# 1468                                    21
# 1470                                    37
# 1471                                    22
# 1472                                    40
#
#       Number of similar products purchased so far  \
# 0                                               4
# 2                                              10
# 4                                               5
# 6                                              15
# 9                                               4
# ...                                           ...
# 1467                                           14
# ...

# %% [markdown]
# __Q13. Create new column 'Price Difference'?
# By using (Price of the product - Median Purchasing Price)__

# %%
df['Price Difference']= df['Price of the product'] - df['Median purchasing price (in rupees)']

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1474 entries, 0 to 1473
# Data columns (total 14 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   Number of clicks on similar products                         1474 non-null   int64
#  1   Number of similar products purchased so far                  1474 non-null   int64
#  2   Average rating given to similar products                     1474 non-null   float64
#  3   Gender                                                       1474 non-null   str
#  4   Median purchasing price (in rupees)                          1474 non-null   int64
#  5   Rating of the product                                        1474 non-null   float64
#  6   Brand of the product                                         1474 non-null   str
# ...

# %% [markdown]
# __Q14. GroupBy average price by Gender?__

# %%
df.groupby('Gender')['Price of the product'].mean()
# Out:
# Gender
# female     699.958333
# male      1565.888594
# Name: Price of the product, dtype: float64

# %% [markdown]
# __Q15. Create histogram Price of the product?__

# %%
df['Price of the product'].plot(kind = 'hist')
plt.show()

# %% [markdown]
# __Conclusion:__

# %% [markdown]
# __Which factor influences recommendations the most?__

# %% [markdown]
# The rating of the product appears to influence recommendations the most,
# as products with higher ratings (above 4) are considered better and are more likely to be recommended

# %% [markdown]
# __What changes did you observe after cleaning the data?__

# %% [markdown]
# After cleaning the data, 456 duplicate rows were identified and removed, which improved the accuracy and reliability of the dataset.
# There were no missing values in the dataset, so no imputation was required.
# Overall, the dataset became more consistent and suitable for analysis

# %% [markdown]
# __One interesting pattern you found__

# %% [markdown]
# An interesting pattern observed is that product prices vary significantly, and higher prices do not always correspond to higher ratings.
# This suggests that customer satisfaction is influenced by factors other than price.
