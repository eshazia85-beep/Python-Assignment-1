# %%
print("Solution of Question no 5")
print("--------------------------")

first = input("Enter your first name: ")
last = input("Enter your last name: ")

print(last + " " + first)
# Out:
# Solution of Question no 5
# --------------------------
# Enter your first name:  esha
# Enter your last name:  zia
# zia esha
