# %%
print("Solution of Question no 3")
print("--------------------------")

import datetime
current = datetime.datetime.now()

print(current)
# Out:
# Solution of Question no 3
# --------------------------
# 2026-02-26 21:57:59.462000
