# %%
print("Solution of Question no 4")
print("--------------------------")

radius = float(input("Enter radius of a circle: "))

Area =  3.142 * (radius)**2

print("The Area of a circle is: ", Area)
# Out:
# Solution of Question no 4
# --------------------------
# Enter radius of a circle:  8
# The Area of a circle is:  201.088
