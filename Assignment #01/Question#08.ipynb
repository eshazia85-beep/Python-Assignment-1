# %%
print("Solution of Question no 8")
print("--------------------------")

num = int(input("Enter a number: "))

if num % 2 == 0:
    print("Number is Even")
else:
    print("Number is odd")
# Out:
# Solution of Question no 8
# --------------------------
# Enter a number:  6
# Number is Even
